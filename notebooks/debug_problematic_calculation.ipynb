# %%
import pandas as pd

# %%
hbi_df = pd.read_csv("../data/hbi_unc.csv")
hbi_df
# Out:
#                  radical_smiles   resonance_radical_smiles  \
# 0             [O]C(=O)OC(O)(O)O          [O]C(=O)OC(O)(O)O
# 1             [O]C(O)(O)OC(=O)O          [O]C(O)(O)OC(=O)O
# 2                O=C(O)O[C](O)O             O=C(O)O[C](O)O
# 3     CC(=O)OC(OO)C(=O)C(O)O[O]  CC(=O)OC(OO)C(=O)C(O)O[O]
# 4                O=[C]OC(O)(O)O             O=[C]OC(O)(O)O
# ...                         ...                        ...
# 2804                C1=C[CH]C=1                 [C]1=CC=C1
# 2805              C=C=C1C=[C]C1              C=C=C1C=[C]C1
# 2806             [CH2]C1=CC#CC1             [CH2]C1=CC#CC1
# 2807             [CH2]C1=CC#CC1              C=C1[CH]C#CC1
# 2808             [CH2]C1=CC#CC1              C=C1C=C=[C]C1
#
#       resonance_radical_num_rotatable_bonds  radical_H298 (kcal/mol)  \
# 0                                         4              -223.514126
# 1                                         3              -223.423390
# ...

# %%
hbi_df[hbi_df["resonance_radical_smiles"]=="C1#CC=CC[CH]1"]
# Out:
#       radical_smiles resonance_radical_smiles  \
# 2795  C1=C=CC[CH]C=1            C1#CC=CC[CH]1
#
#       resonance_radical_num_rotatable_bonds  radical_H298 (kcal/mol)  \
# 2795                                      0               139.224273
#
#       radical_Sint298 (cal/mol/K)     radical_source radical_level_of_theory  \
# 2795                    73.089716  dong_pio_liang.py                 CBS-QB3
#
#       radical_Cp300 (cal/mol/K)  radical_Cp400 (cal/mol/K)  \
# 2795                  21.439563                  27.184618
#
#       radical_Cp500 (cal/mol/K)  ...  unc_closed_shell_Cp1500 (cal/mol/K)  \
# 2795                  32.155575  ...                                  2.0
#
#       unc_HBI_H298 (kcal/mol)  unc_HBI_Sint298 (cal/mol/K)  \
# 2795                      5.2                          3.0
#
#       unc_HBI_Cp300 (cal/mol/K) unc_HBI_Cp400 (cal/mol/K)  \
# 2795                        3.0                       3.0
#
# ...
