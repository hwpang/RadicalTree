# %% [markdown]
# # Get HBI data

# %%
import sys
sys.path.insert(0,"/home/gridsan/hwpang/Software/RMG-Py/")
sys.path.insert(0,"..")

import random
import os
import time
import math
from copy import deepcopy
import pandas as pd
from joblib import Parallel, delayed
from tqdm import tqdm

from rmgpy.data.thermo import ThermoDatabase, ThermoLibrary, ThermoData, remove_thermo_data, add_thermo_data, NASA
from rmgpy.molecule import Molecule
from rmgpy.species import Species
from rmgpy import settings
from rmgpy import constants

from tree.utils import load_thermo_lib_by_path, generate_thermo
from tree.parameters import Ts
# Out:
# WARNING:root:No normalization for BCUT2D_MWHI
# WARNING:root:No normalization for BCUT2D_MWLOW
# WARNING:root:No normalization for BCUT2D_CHGHI
# WARNING:root:No normalization for BCUT2D_CHGLO
# WARNING:root:No normalization for BCUT2D_LOGPHI
# WARNING:root:No normalization for BCUT2D_LOGPLOW
# WARNING:root:No normalization for BCUT2D_MRHI
# WARNING:root:No normalization for BCUT2D_MRLOW

# %% [markdown]
# # Load data to join

# %%
radical_data_df = pd.read_csv("../data/radical_data_no_dup.csv")
resonance_radical_df = pd.read_csv("../data/resonance_radicals.csv")
closed_shell_data_df = pd.read_csv("../data/closed_shell_data.csv")

# %%
resonance_radical_df
# Out:
#                  radical_smiles   resonance_radical_smiles  has_H  has_C  \
# 0             [O]C(=O)OC(O)(O)O          [O]C(=O)OC(O)(O)O   True   True
# 1             [O]C(O)(O)OC(=O)O          [O]C(O)(O)OC(=O)O   True   True
# 2                O=C(O)O[C](O)O             O=C(O)O[C](O)O   True   True
# 3     CC(=O)OC(OO)C(=O)C(O)O[O]  CC(=O)OC(OO)C(=O)C(O)O[O]   True   True
# 4                O=[C]OC(O)(O)O             O=[C]OC(O)(O)O   True   True
# ...                         ...                        ...    ...    ...
# 2800                C1=C[CH]C=1                 [C]1=CC=C1   True   True
# 2801              C=C=C1C=[C]C1              C=C=C1C=[C]C1   True   True
# 2802             [CH2]C1=CC#CC1             [CH2]C1=CC#CC1   True   True
# 2803             [CH2]C1=CC#CC1              C=C1[CH]C#CC1   True   True
# 2804             [CH2]C1=CC#CC1              C=C1C=C=[C]C1   True   True
#
#       has_N  has_O  Mw (g/mol)  num_rings  num_heavy_atoms  \
# 0     False   True  122.992963          0                8
# 1     False   True  122.992963          0                8
# 2     False   True  106.998048          0                7
# 3     False   True  195.014092          0               13
# 4     False   True  106.998048          0                7
# ...     ...    ...         ...        ...              ...
# 2800  False  False   51.023475          1                4
# 2801  False  False   77.039125          1                6
# 2802  False  False   77.039125          1                6
# 2803  False  False   77.039125          1                6
# 2804  False  False   77.039125          1                6
#
#       num_rotatable_bonds radical_atom_type
# 0                       4                 O
# 1                       3                 O
# 2                       3                 C
# 3                       8                 O
# 4                       5                 C
# ...                   ...               ...
# 2800                    0                 C
# 2801                    0                 C
# 2802                    1                 C
# 2803                    0                 C
# 2804                    0                 C
#
# [2805 rows x 11 columns]

# %%
radical_data_df
# Out:
#                          smiles  H298 (kcal/mol)  S298 (cal/mol/K)  \
# 0             [O]C(=O)OC(O)(O)O      -223.514126         93.816804
# 1             [O]C(O)(O)OC(=O)O      -223.423390         92.781436
# 2                O=C(O)O[C](O)O      -187.322869         88.139642
# 3     CC(=O)OC(OO)C(=O)C(O)O[O]      -185.660577        133.205064
# 4                O=[C]OC(O)(O)O      -180.497563         87.848805
# ...                         ...              ...               ...
# 2205             C=C=C1[CH]C1=C       148.970420         78.606070
# 2206                [CH]=C1C=C1       152.166735         66.134536
# 2207                C1=C[CH]C=1       156.106582         64.008341
# 2208              C=C=C1C=[C]C1       157.733085         76.210198
# 2209             [CH2]C1=CC#CC1       163.498344         74.586417
#
#       Sint298 (cal/mol/K)             source level_of_theory  \
# 0               95.999974  dong_pio_liang.py         CBS-QB3
# 1               92.781436  dong_pio_liang.py         CBS-QB3
# 2               89.517068  dong_pio_liang.py         CBS-QB3
# 3              132.633380  dong_pio_liang.py         CBS-QB3
# 4               90.031975  dong_pio_liang.py         CBS-QB3
# ...                   ...                ...             ...
# 2205            81.360924  dong_pio_liang.py         CBS-QB3
# 2206            67.511963  dong_pio_liang.py         CBS-QB3
# 2207            65.385768  dong_pio_liang.py         CBS-QB3
# 2208            77.587625  dong_pio_liang.py         CBS-QB3
# 2209            75.963844  dong_pio_liang.py         CBS-QB3
#
#       Cp300 (cal/mol/K)  Cp400 (cal/mol/K)  Cp500 (cal/mol/K)  \
# 0             33.926878          38.387673          41.508496
# 1             32.531179          37.569659          41.498443
# 2             28.973242          34.553073          38.746721
# 3             56.569703          66.028226          73.603744
# 4             32.378191          36.844343          39.334179
# ...                 ...                ...                ...
# 2205          25.185446          30.771706          34.989720
# 2206          16.390064          19.702535          22.399354
# 2207          14.653111          18.488757          21.562144
# 2208          22.675255          28.333884          32.976246
# 2209          22.606638          28.495118          33.391100
#
#       Cp600 (cal/mol/K)  Cp800 (cal/mol/K)  Cp1000 (cal/mol/K)  \
# 0             44.062390          47.779730           50.089328
# 1             44.710460          49.355989           52.184758
# 2             41.655671          45.237515           47.423507
# 3             79.772844          88.705511           94.174908
# 4             41.301130          44.143726           45.893560
# ...                 ...                ...                 ...
# 2205          38.456637          43.926501           47.843872
# 2206          24.484680          27.637313           29.841300
# 2207          23.855179          27.322032           29.749165
# 2208          36.811783          42.847715           47.149236
# 2209          37.327959          43.401164           47.644478
#
#       Cp1500 (cal/mol/K)
# 0              52.510168
# 1              54.821371
# 2              49.461069
# 3              99.503777
# 4              47.744589
# ...                  ...
# 2205           53.411105
# 2206           32.891319
# 2207           33.017640
# 2208           53.155423
# 2209           53.388267
#
# [2210 rows x 13 columns]

# %% [markdown]
# # Join data

# %%
temp_radical_data_df = radical_data_df
temp_radical_data_df = temp_radical_data_df.rename(columns={column: "radical_"+column for column in radical_data_df.columns})
temp_radical_data_df = temp_radical_data_df.drop(columns="radical_S298 (cal/mol/K)")
temp_radical_data_df
# Out:
#                  radical_smiles  radical_H298 (kcal/mol)  \
# 0             [O]C(=O)OC(O)(O)O              -223.514126
# 1             [O]C(O)(O)OC(=O)O              -223.423390
# 2                O=C(O)O[C](O)O              -187.322869
# 3     CC(=O)OC(OO)C(=O)C(O)O[O]              -185.660577
# 4                O=[C]OC(O)(O)O              -180.497563
# ...                         ...                      ...
# 2205             C=C=C1[CH]C1=C               148.970420
# 2206                [CH]=C1C=C1               152.166735
# 2207                C1=C[CH]C=1               156.106582
# 2208              C=C=C1C=[C]C1               157.733085
# 2209             [CH2]C1=CC#CC1               163.498344
#
#       radical_Sint298 (cal/mol/K)     radical_source radical_level_of_theory  \
# 0                       95.999974  dong_pio_liang.py                 CBS-QB3
# 1                       92.781436  dong_pio_liang.py                 CBS-QB3
# 2                       89.517068  dong_pio_liang.py                 CBS-QB3
# 3                      132.633380  dong_pio_liang.py                 CBS-QB3
# 4                       90.031975  dong_pio_liang.py                 CBS-QB3
# ...                           ...                ...                     ...
# 2205                    81.360924  dong_pio_liang.py                 CBS-QB3
# 2206                    67.511963  dong_pio_liang.py                 CBS-QB3
# 2207                    65.385768  dong_pio_liang.py                 CBS-QB3
# 2208                    77.587625  dong_pio_liang.py                 CBS-QB3
# 2209                    75.963844  dong_pio_liang.py                 CBS-QB3
#
#       radical_Cp300 (cal/mol/K)  radical_Cp400 (cal/mol/K)  \
# 0                     33.926878                  38.387673
# 1                     32.531179                  37.569659
# 2                     28.973242                  34.553073
# 3                     56.569703                  66.028226
# 4                     32.378191                  36.844343
# ...                         ...                        ...
# 2205                  25.185446                  30.771706
# 2206                  16.390064                  19.702535
# 2207                  14.653111                  18.488757
# 2208                  22.675255                  28.333884
# 2209                  22.606638                  28.495118
#
#       radical_Cp500 (cal/mol/K)  radical_Cp600 (cal/mol/K)  \
# 0                     41.508496                  44.062390
# 1                     41.498443                  44.710460
# 2                     38.746721                  41.655671
# 3                     73.603744                  79.772844
# 4                     39.334179                  41.301130
# ...                         ...                        ...
# 2205                  34.989720                  38.456637
# 2206                  22.399354                  24.484680
# 2207                  21.562144                  23.855179
# 2208                  32.976246                  36.811783
# 2209                  33.391100                  37.327959
#
#       radical_Cp800 (cal/mol/K)  radical_Cp1000 (cal/mol/K)  \
# 0                     47.779730                   50.089328
# 1                     49.355989                   52.184758
# 2                     45.237515                   47.423507
# 3                     88.705511                   94.174908
# 4                     44.143726                   45.893560
# ...                         ...                         ...
# 2205                  43.926501                   47.843872
# 2206                  27.637313                   29.841300
# 2207                  27.322032                   29.749165
# 2208                  42.847715                   47.149236
# 2209                  43.401164                   47.644478
#
#       radical_Cp1500 (cal/mol/K)
# 0                      52.510168
# 1                      54.821371
# 2                      49.461069
# 3                      99.503777
# 4                      47.744589
# ...                          ...
# 2205                   53.411105
# 2206                   32.891319
# 2207                   33.017640
# 2208                   53.155423
# 2209                   53.388267
#
# [2210 rows x 12 columns]

# %%
temp_closed_shell_data_df = closed_shell_data_df.drop(columns="closed_shell_S298 (cal/mol/K)")

# %%
temp_closed_shell_data_df["resonance_radical_smiles"].value_counts()
# Out:
# [O]C(=O)OC(O)(O)O           1
# C=C(C)COOC1C=C(C)[CH]CC1    1
# C=C([CH]C)OO                1
# [CH2]C(=CC)OO               1
# C=C(C)C[C]=O                1
#                            ..
# [O]CO                       1
# CC(CCOO)O[O]                1
# [CH2]C(=C)C(C)(CO)OO        1
# [CH2]OCOC                   1
# C=C1C=C=[C]C1               1
# Name: resonance_radical_smiles, Length: 2805, dtype: int64

# %%
hbi_df = resonance_radical_df[["radical_smiles", "resonance_radical_smiles", "num_rotatable_bonds"]]
hbi_df = hbi_df.rename(columns={"num_rotatable_bonds": "resonance_radical_num_rotatable_bonds"})
hbi_df = hbi_df.merge(temp_radical_data_df, on="radical_smiles", how="left")
hbi_df = hbi_df.merge(temp_closed_shell_data_df, on="resonance_radical_smiles", how="left")
hbi_df
# Out:
#                  radical_smiles   resonance_radical_smiles  \
# 0             [O]C(=O)OC(O)(O)O          [O]C(=O)OC(O)(O)O
# 1             [O]C(O)(O)OC(=O)O          [O]C(O)(O)OC(=O)O
# 2                O=C(O)O[C](O)O             O=C(O)O[C](O)O
# 3     CC(=O)OC(OO)C(=O)C(O)O[O]  CC(=O)OC(OO)C(=O)C(O)O[O]
# 4                O=[C]OC(O)(O)O             O=[C]OC(O)(O)O
# ...                         ...                        ...
# 2800                C1=C[CH]C=1                 [C]1=CC=C1
# 2801              C=C=C1C=[C]C1              C=C=C1C=[C]C1
# 2802             [CH2]C1=CC#CC1             [CH2]C1=CC#CC1
# 2803             [CH2]C1=CC#CC1              C=C1[CH]C#CC1
# 2804             [CH2]C1=CC#CC1              C=C1C=C=[C]C1
#
#       resonance_radical_num_rotatable_bonds  radical_H298 (kcal/mol)  \
# 0                                         4              -223.514126
# 1                                         3              -223.423390
# 2                                         3              -187.322869
# 3                                         8              -185.660577
# 4                                         5              -180.497563
# ...                                     ...                      ...
# 2800                                      0               156.106582
# 2801                                      0               157.733085
# 2802                                      1               163.498344
# 2803                                      0               163.498344
# 2804                                      0               163.498344
#
#       radical_Sint298 (cal/mol/K)     radical_source radical_level_of_theory  \
# 0                       95.999974  dong_pio_liang.py                 CBS-QB3
# 1                       92.781436  dong_pio_liang.py                 CBS-QB3
# 2                       89.517068  dong_pio_liang.py                 CBS-QB3
# 3                      132.633380  dong_pio_liang.py                 CBS-QB3
# 4                       90.031975  dong_pio_liang.py                 CBS-QB3
# ...                           ...                ...                     ...
# 2800                    65.385768  dong_pio_liang.py                 CBS-QB3
# 2801                    77.587625  dong_pio_liang.py                 CBS-QB3
# 2802                    75.963844  dong_pio_liang.py                 CBS-QB3
# 2803                    75.963844  dong_pio_liang.py                 CBS-QB3
# 2804                    75.963844  dong_pio_liang.py                 CBS-QB3
#
#       radical_Cp300 (cal/mol/K)  radical_Cp400 (cal/mol/K)  \
# 0                     33.926878                  38.387673
# 1                     32.531179                  37.569659
# 2                     28.973242                  34.553073
# 3                     56.569703                  66.028226
# 4                     32.378191                  36.844343
# ...                         ...                        ...
# 2800                  14.653111                  18.488757
# 2801                  22.675255                  28.333884
# 2802                  22.606638                  28.495118
# 2803                  22.606638                  28.495118
# 2804                  22.606638                  28.495118
#
#       radical_Cp500 (cal/mol/K)  ...  closed_shell_Cp300 (cal/mol/K)  \
# 0                     41.508496  ...                       31.562314
# 1                     41.498443  ...                       31.562314
# 2                     38.746721  ...                       27.214474
# 3                     73.603744  ...                       52.706616
# 4                     39.334179  ...                       26.935163
# ...                         ...  ...                             ...
# 2800                  21.562144  ...                       15.504000
# 2801                  32.976246  ...                       22.416919
# 2802                  33.391100  ...                       23.409000
# 2803                  33.391100  ...                       22.819000
# 2804                  33.391100  ...                       23.109770
#
#       closed_shell_Cp400 (cal/mol/K)  closed_shell_Cp500 (cal/mol/K)  \
# 0                          36.827897                       41.095602
# 1                          36.827897                       41.095602
# 2                          31.965583                       36.032333
# 3                          62.438776                       71.442505
# 4                          30.962696                       34.637667
# ...                              ...                             ...
# 2800                       19.920000                       23.474000
# 2801                       29.489266                       35.000461
# 2802                       30.017000                       34.619000
# 2803                       29.017000                       34.189000
# 2804                       30.529630                       36.181680
#
#       closed_shell_Cp600 (cal/mol/K) closed_shell_Cp800 (cal/mol/K)  \
# 0                          44.234417                      48.821415
# 1                          44.234417                      48.821415
# 2                          39.309560                      44.059044
# 3                          78.070363                      87.443365
# 4                          37.592447                      42.375430
# ...                              ...                            ...
# 2800                       26.261000                      30.329000
# 2801                       39.185145                      45.162263
# 2802                       39.828000                      46.529000
# 2803                       38.448000                      45.419000
# 2804                       40.339270                      46.666770
#
#       closed_shell_Cp1000 (cal/mol/K)  closed_shell_Cp1500 (cal/mol/K)  \
# 0                           51.772505                        56.215621
# 1                           51.772505                        56.215621
# 2                           47.141300                        50.458700
# 3                           95.103078                       102.679981
# 4                           45.749560                        50.979006
# ...                               ...                              ...
# 2800                        33.199000                        37.574000
# 2801                        49.240044                        55.323950
# 2802                        51.356000                        56.349000
# 2803                        50.576000                        55.959000
# 2804                        51.760220                        58.299980
#
#       closed_shell_Sint298 (cal/mol/K)  \
# 0                           100.589618
# 1                           100.589618
# 2                            94.127419
# 3                           145.026864
# 4                            94.867820
# ...                                ...
# 2800                         61.950300
# 2801                         51.772385
# 2802                         75.140000
# 2803                         75.190000
# 2804                         70.312300
#
#                             closed_shell_thermo_comment  \
# 0     Thermo group additivity estimation: group(O2s-...
# 1     Thermo group additivity estimation: group(O2s-...
# 2     Thermo group additivity estimation: group(O2s-...
# 3     Thermo group additivity estimation: group(O2s-...
# 4     Thermo group additivity estimation: group(O2s-...
# ...                                                 ...
# 2800  Thermo group additivity estimation: group(Cds-...
# 2801  Thermo group additivity estimation: group(Cs-(...
# 2802  Thermo group additivity estimation: group(Cs-(...
# 2803  Thermo group additivity estimation: group(Cs-(...
# 2804  Thermo group additivity estimation: group(Cs-(...
#
#       closed_shell_thermo_source
# 0                            GAV
# 1                            GAV
# 2                            GAV
# 3                            GAV
# 4                            GAV
# ...                          ...
# 2800                         GAV
# 2801                         GAV
# 2802                         GAV
# 2803                         GAV
# 2804                         GAV
#
# [2805 rows x 26 columns]

# %% [markdown]
# # Derive HBI corrections

# %%
properties = ["H298 (kcal/mol)", "Sint298 (cal/mol/K)"]
for T in Ts:
    properties.append(f"Cp{T} (cal/mol/K)")

hbi_df[f"HBI_H298 (kcal/mol)"] = hbi_df[f"radical_H298 (kcal/mol)"] - hbi_df[f"closed_shell_H298 (kcal/mol)"] + 52.1

for prop in properties[1:]:
    hbi_df[f"HBI_{prop}"] = hbi_df[f"radical_{prop}"] - hbi_df[f"closed_shell_{prop}"]
    
hbi_df
# Out:
#                  radical_smiles   resonance_radical_smiles  \
# 0             [O]C(=O)OC(O)(O)O          [O]C(=O)OC(O)(O)O
# 1             [O]C(O)(O)OC(=O)O          [O]C(O)(O)OC(=O)O
# 2                O=C(O)O[C](O)O             O=C(O)O[C](O)O
# 3     CC(=O)OC(OO)C(=O)C(O)O[O]  CC(=O)OC(OO)C(=O)C(O)O[O]
# 4                O=[C]OC(O)(O)O             O=[C]OC(O)(O)O
# ...                         ...                        ...
# 2800                C1=C[CH]C=1                 [C]1=CC=C1
# 2801              C=C=C1C=[C]C1              C=C=C1C=[C]C1
# 2802             [CH2]C1=CC#CC1             [CH2]C1=CC#CC1
# 2803             [CH2]C1=CC#CC1              C=C1[CH]C#CC1
# 2804             [CH2]C1=CC#CC1              C=C1C=C=[C]C1
#
#       resonance_radical_num_rotatable_bonds  radical_H298 (kcal/mol)  \
# 0                                         4              -223.514126
# 1                                         3              -223.423390
# 2                                         3              -187.322869
# 3                                         8              -185.660577
# 4                                         5              -180.497563
# ...                                     ...                      ...
# 2800                                      0               156.106582
# 2801                                      0               157.733085
# 2802                                      1               163.498344
# 2803                                      0               163.498344
# 2804                                      0               163.498344
#
#       radical_Sint298 (cal/mol/K)     radical_source radical_level_of_theory  \
# 0                       95.999974  dong_pio_liang.py                 CBS-QB3
# 1                       92.781436  dong_pio_liang.py                 CBS-QB3
# 2                       89.517068  dong_pio_liang.py                 CBS-QB3
# 3                      132.633380  dong_pio_liang.py                 CBS-QB3
# 4                       90.031975  dong_pio_liang.py                 CBS-QB3
# ...                           ...                ...                     ...
# 2800                    65.385768  dong_pio_liang.py                 CBS-QB3
# 2801                    77.587625  dong_pio_liang.py                 CBS-QB3
# 2802                    75.963844  dong_pio_liang.py                 CBS-QB3
# 2803                    75.963844  dong_pio_liang.py                 CBS-QB3
# 2804                    75.963844  dong_pio_liang.py                 CBS-QB3
#
#       radical_Cp300 (cal/mol/K)  radical_Cp400 (cal/mol/K)  \
# 0                     33.926878                  38.387673
# 1                     32.531179                  37.569659
# 2                     28.973242                  34.553073
# 3                     56.569703                  66.028226
# 4                     32.378191                  36.844343
# ...                         ...                        ...
# 2800                  14.653111                  18.488757
# 2801                  22.675255                  28.333884
# 2802                  22.606638                  28.495118
# 2803                  22.606638                  28.495118
# 2804                  22.606638                  28.495118
#
#       radical_Cp500 (cal/mol/K)  ...  closed_shell_thermo_source  \
# 0                     41.508496  ...                         GAV
# 1                     41.498443  ...                         GAV
# 2                     38.746721  ...                         GAV
# 3                     73.603744  ...                         GAV
# 4                     39.334179  ...                         GAV
# ...                         ...  ...                         ...
# 2800                  21.562144  ...                         GAV
# 2801                  32.976246  ...                         GAV
# 2802                  33.391100  ...                         GAV
# 2803                  33.391100  ...                         GAV
# 2804                  33.391100  ...                         GAV
#
#       HBI_H298 (kcal/mol)  HBI_Sint298 (cal/mol/K)  HBI_Cp300 (cal/mol/K)  \
# 0              101.203465                -4.589644               2.364565
# 1              101.294200                -7.808181               0.968866
# 2               96.140974                -4.610350               1.758768
# 3              100.658735               -12.393484               3.863088
# 4               88.101481                -4.835845               5.443029
# ...                   ...                      ...                    ...
# 2800           103.873082                 3.435468              -0.850889
# 2801           118.466211                25.815240               0.258337
# 2802            84.371344                 0.823844              -0.802362
# 2803            78.831344                 0.773844              -0.212362
# 2804            89.324944                 5.651544              -0.503132
#
#      HBI_Cp400 (cal/mol/K)  HBI_Cp500 (cal/mol/K)  HBI_Cp600 (cal/mol/K)  \
# 0                 1.559776               0.412894              -0.172027
# 1                 0.741762               0.402841               0.476043
# 2                 2.587490               2.714389               2.346110
# 3                 3.589450               2.161239               1.702481
# 4                 5.881647               4.696512               3.708683
# ...                    ...                    ...                    ...
# 2800             -1.431243              -1.911856              -2.405821
# 2801             -1.155381              -2.024215              -2.373362
# 2802             -1.521882              -1.227900              -2.500041
# 2803             -0.521882              -0.797900              -1.120041
# 2804             -2.034512              -2.790580              -3.011311
#
#       HBI_Cp800 (cal/mol/K)  HBI_Cp1000 (cal/mol/K)  HBI_Cp1500 (cal/mol/K)
# 0                 -1.041685               -1.683176               -3.705453
# 1                  0.534574                0.412253               -1.394250
# 2                  1.178471                0.282207               -0.997631
# 3                  1.262146               -0.928170               -3.176204
# 4                  1.768296                0.144000               -3.234417
# ...                     ...                     ...                     ...
# 2800              -3.006968               -3.449835               -4.556360
# 2801              -2.314548               -2.090808               -2.168527
# 2802              -3.127836               -3.711522               -2.960733
# 2803              -2.017836               -2.931522               -2.570733
# 2804              -3.265606               -4.115742               -4.911713
#
# [2805 rows x 35 columns]

# %%
hbi_df.to_csv("../data/hbi.csv", index=False)
