# %% [markdown]
# # Get HBI data

# %%
import sys
sys.path.insert(0,"/home/gridsan/hwpang/Software/RMG-Py/")

import random
import os
import time
import math
from copy import deepcopy
import pandas as pd
from joblib import Parallel, delayed
from tqdm import tqdm

from utils import load_thermo_lib_by_path, generate_thermo

from rmgpy.data.thermo import ThermoDatabase, ThermoLibrary, ThermoData, remove_thermo_data, add_thermo_data, NASA
from rmgpy.molecule import Molecule
from rmgpy.species import Species
from rmgpy import settings
from rmgpy import constants

# %% [markdown]
# # Generate resonance structure data

# %%
radical_df = pd.read_csv("../data/radical.csv")
radical_df
# Out:
#                          smiles  H298 (kcal/mol)  S298 (cal/mol/K)  \
# 0             [O]C(=O)OC(O)(O)O      -223.514126         93.816804
# 1             [O]C(O)(O)OC(=O)O      -223.423390         92.781436
# 2                O=C(O)O[C](O)O      -187.322869         88.139642
# 3     CC(=O)OC(OO)C(=O)C(O)O[O]      -185.660577        133.205064
# 4                O=[C]OC(O)(O)O      -180.497563         87.848805
# ...                         ...              ...               ...
# 2232             C=C=C1[CH]C1=C       148.970420         78.606070
# 2233                [CH]=C1C=C1       152.166735         66.134536
# 2234                C1=C[CH]C=1       156.106582         64.008341
# 2235              C=C=C1C=[C]C1       157.733085         76.210198
# 2236             [CH2]C1=CC#CC1       163.498344         74.586417
#
#       Sint298 (cal/mol/K)             source level_of_theory  \
# 0               95.999974  dong_pio_liang.py         CBS-QB3
# 1               92.781436  dong_pio_liang.py         CBS-QB3
# 2               89.517068  dong_pio_liang.py         CBS-QB3
# 3              132.633380  dong_pio_liang.py         CBS-QB3
# 4               90.031975  dong_pio_liang.py         CBS-QB3
# ...                   ...                ...             ...
# 2232            81.360924  dong_pio_liang.py         CBS-QB3
# 2233            67.511963  dong_pio_liang.py         CBS-QB3
# 2234            65.385768  dong_pio_liang.py         CBS-QB3
# 2235            77.587625  dong_pio_liang.py         CBS-QB3
# 2236            75.963844  dong_pio_liang.py         CBS-QB3
#
#       Cp300 (cal/mol/K)  Cp400 (cal/mol/K)  Cp500 (cal/mol/K)  \
# 0             33.926878          38.387673          41.508496
# 1             32.531179          37.569659          41.498443
# 2             28.973242          34.553073          38.746721
# 3             56.569703          66.028226          73.603744
# 4             32.378191          36.844343          39.334179
# ...                 ...                ...                ...
# 2232          25.185446          30.771706          34.989720
# 2233          16.390064          19.702535          22.399354
# 2234          14.653111          18.488757          21.562144
# 2235          22.675255          28.333884          32.976246
# 2236          22.606638          28.495118          33.391100
#
#       Cp600 (cal/mol/K)  Cp800 (cal/mol/K)  Cp1000 (cal/mol/K)  \
# 0             44.062390          47.779730           50.089328
# 1             44.710460          49.355989           52.184758
# 2             41.655671          45.237515           47.423507
# 3             79.772844          88.705511           94.174908
# 4             41.301130          44.143726           45.893560
# ...                 ...                ...                 ...
# 2232          38.456637          43.926501           47.843872
# 2233          24.484680          27.637313           29.841300
# 2234          23.855179          27.322032           29.749165
# 2235          36.811783          42.847715           47.149236
# 2236          37.327959          43.401164           47.644478
#
#       Cp1500 (cal/mol/K)  num_resonance
# 0              52.510168              1
# 1              54.821371              1
# 2              49.461069              1
# 3              99.503777              1
# 4              47.744589              1
# ...                  ...            ...
# 2232           53.411105              3
# 2233           32.891319              1
# 2234           33.017640              2
# 2235           53.155423              1
# 2236           53.388267              3
#
# [2237 rows x 14 columns]

# %%
def generate_radical_resonance_smis(smi):
    rad = Molecule().from_smiles(smi)
    rads = [r for r in rad.generate_resonance_structures() if sum(atom.radical_electrons for atom in r.atoms)==1]
    for r in rads:
        r.atoms.sort()
    return [r.to_smiles() for r in rads]
    
generate_radical_resonance_smis("C[CH]C(=O)OCO")
# Out:
# ['C[CH]C(=O)OCO', 'CC=C([O])OCO']

# %%
resonance_smiss = [generate_radical_resonance_smis(smi) for smi in tqdm(radical_df["smiles"])]
# Out:
# 100%|██████████| 2237/2237 [00:25<00:00, 86.91it/s]

# %%
temp_dict = {
    "radical_smiles": [],
    "radical_resonance_smiles": [],
}

# %%
for smi, resonance_smis in zip(radical_df["smiles"], resonance_smiss):
    for resonance_smi in resonance_smis:
        temp_dict["radical_smiles"].append(smi)
        temp_dict["radical_resonance_smiles"].append(resonance_smi)

HBI_correction_df = pd.DataFrame(temp_dict)
HBI_correction_df
# Out:
#                  radical_smiles   radical_resonance_smiles
# 0             [O]C(=O)OC(O)(O)O          [O]C(=O)OC(O)(O)O
# 1             [O]C(O)(O)OC(=O)O          [O]C(O)(O)OC(=O)O
# 2                O=C(O)O[C](O)O             O=C(O)O[C](O)O
# 3     CC(=O)OC(OO)C(=O)C(O)O[O]  CC(=O)OC(OO)C(=O)C(O)O[O]
# 4                O=[C]OC(O)(O)O             O=[C]OC(O)(O)O
# ...                         ...                        ...
# 2862                C1=C[CH]C=1                 [C]1=CC=C1
# 2863              C=C=C1C=[C]C1              C=C=C1C=[C]C1
# 2864             [CH2]C1=CC#CC1             [CH2]C1=CC#CC1
# 2865             [CH2]C1=CC#CC1              C=C1[CH]C#CC1
# 2866             [CH2]C1=CC#CC1              C=C1C=C=[C]C1
#
# [2867 rows x 2 columns]

# %%
HBI_correction_df.to_csv("../data/hbi.csv", index=False)

# %% [markdown]
# # Generate closed shell structures

# %%
def generate_closed_shell_smi(smi):
    mol = Molecule().from_smiles(smi)
    mol.saturate_radicals()
    mol.atoms.sort()
    return mol.to_smiles()

generate_closed_shell_smi("CC1OC1OC[O]")
# Out:
# 'CC1OC1OCO'

# %%
HBI_correction_df = pd.read_csv("../data/hbi.csv")

# %%
HBI_correction_df["closed_shell_smiles"] = HBI_correction_df["radical_resonance_smiles"].apply(generate_closed_shell_smi)
HBI_correction_df
# Out:
#                  radical_smiles   radical_resonance_smiles  \
# 0             [O]C(=O)OC(O)(O)O          [O]C(=O)OC(O)(O)O
# 1             [O]C(O)(O)OC(=O)O          [O]C(O)(O)OC(=O)O
# 2                O=C(O)O[C](O)O             O=C(O)O[C](O)O
# 3     CC(=O)OC(OO)C(=O)C(O)O[O]  CC(=O)OC(OO)C(=O)C(O)O[O]
# 4                O=[C]OC(O)(O)O             O=[C]OC(O)(O)O
# ...                         ...                        ...
# 2862                C1=C[CH]C=1                 [C]1=CC=C1
# 2863              C=C=C1C=[C]C1              C=C=C1C=[C]C1
# 2864             [CH2]C1=CC#CC1             [CH2]C1=CC#CC1
# 2865             [CH2]C1=CC#CC1              C=C1[CH]C#CC1
# 2866             [CH2]C1=CC#CC1              C=C1C=C=[C]C1
#
#           closed_shell_smiles
# 0             O=C(O)OC(O)(O)O
# 1             O=C(O)OC(O)(O)O
# 2                O=C(O)OC(O)O
# 3     CC(=O)OC(OO)C(=O)C(O)OO
# 4                O=COC(O)(O)O
# ...                       ...
# 2862                 C1=CC=C1
# 2863              C=C=C1C=CC1
# 2864               CC1=CC#CC1
# 2865               C=C1CC#CC1
# 2866              C=C1C=C=CC1
#
# [2867 rows x 3 columns]

# %%
HBI_correction_df.to_csv("../data/hbi.csv", index=False)

# %% [markdown]
# # Generate closed shell thermo

# %%
HBI_correction_df = pd.read_csv("../data/hbi.csv")

# %%
lib_paths = [
    "../data/dong_pio_liang.py",
    "../data/pang.py",
    "../data/johnson_cbs-qb3.py",
    "../data/johnson_g4.py",
]
Ts = [300,400,500,600,800,1000,1500]

# %%
# load thermo database

thermo_database = ThermoDatabase()
thermo_database.load_groups(os.path.join(settings["database.directory"], "thermo", "groups"))
for path in lib_paths:
    load_thermo_lib_by_path(path, thermo_database)
    thermo_database.library_order.remove(path)
thermo_database.library_order = lib_paths + thermo_database.library_order
# Out:
# The thermodynamics library ../data/dong_pio_liang.py is loaded.
# The thermodynamics library ../data/pang.py is loaded.
# The thermodynamics library ../data/johnson_cbs-qb3.py is loaded.
# The thermodynamics library ../data/johnson_g4.py is loaded.

# %%
# takes ~1 min 30 sec
closed_shell_thermos = [generate_thermo(thermo_database, smi, resonance=False) for smi in tqdm(HBI_correction_df["closed_shell_smiles"])]
# Out:
# 100%|██████████| 2867/2867 [01:14<00:00, 38.37it/s]

# %%
HBI_correction_df["closed_shell_H298 (kcal/mol)"] = [thermo[0] for thermo in closed_shell_thermos]
HBI_correction_df["closed_shell_S298 (cal/mol/K)"] = [thermo[1] for thermo in closed_shell_thermos]
for i, T in enumerate(Ts):
    HBI_correction_df[f"closed_shell_Cp{T} (cal/mol/K)"] = [thermo[2][i] for thermo in closed_shell_thermos]
HBI_correction_df["closed_shell_Sint298 (cal/mol/K)"] = [thermo[3] for thermo in closed_shell_thermos]
HBI_correction_df["closed_shell_thermo_comment"] = [thermo[4] for thermo in closed_shell_thermos]
HBI_correction_df
# Out:
#                  radical_smiles   radical_resonance_smiles  \
# 0             [O]C(=O)OC(O)(O)O          [O]C(=O)OC(O)(O)O
# 1             [O]C(O)(O)OC(=O)O          [O]C(O)(O)OC(=O)O
# 2                O=C(O)O[C](O)O             O=C(O)O[C](O)O
# 3     CC(=O)OC(OO)C(=O)C(O)O[O]  CC(=O)OC(OO)C(=O)C(O)O[O]
# 4                O=[C]OC(O)(O)O             O=[C]OC(O)(O)O
# ...                         ...                        ...
# 2862                C1=C[CH]C=1                 [C]1=CC=C1
# 2863              C=C=C1C=[C]C1              C=C=C1C=[C]C1
# 2864             [CH2]C1=CC#CC1             [CH2]C1=CC#CC1
# 2865             [CH2]C1=CC#CC1              C=C1[CH]C#CC1
# 2866             [CH2]C1=CC#CC1              C=C1C=C=[C]C1
#
#           closed_shell_smiles  closed_shell_H298 (kcal/mol)  \
# 0             O=C(O)OC(O)(O)O                   -272.617591
# 1             O=C(O)OC(O)(O)O                   -272.617591
# 2                O=C(O)OC(O)O                   -231.363843
# 3     CC(=O)OC(OO)C(=O)C(O)OO                   -234.219312
# 4                O=COC(O)(O)O                   -216.499044
# ...                       ...                           ...
# 2862                 C1=CC=C1                    104.333500
# 2863              C=C=C1C=CC1                     91.366874
# 2864               CC1=CC#CC1                    131.227000
# 2865               C=C1CC#CC1                    136.767000
# 2866              C=C1C=C=CC1                    126.273400
#
#       closed_shell_S298 (cal/mol/K)  closed_shell_Cp300 (cal/mol/K)  \
# 0                         98.406448                       31.562314
# 1                         98.406448                       31.562314
# 2                         94.127419                       27.214474
# 3                        145.598548                       52.706616
# 4                         92.684651                       26.935163
# ...                             ...                             ...
# 2862                      57.818020                       15.504000
# 2863                      50.394958                       22.416919
# 2864                      72.956831                       23.409000
# 2865                      72.435147                       22.819000
# 2866                      68.934873                       23.109770
#
#       closed_shell_Cp400 (cal/mol/K)  closed_shell_Cp500 (cal/mol/K)  \
# 0                          36.827897                       41.095602
# 1                          36.827897                       41.095602
# 2                          31.965583                       36.032333
# 3                          62.438776                       71.442505
# 4                          30.962696                       34.637667
# ...                              ...                             ...
# 2862                       19.920000                       23.474000
# 2863                       29.489266                       35.000461
# 2864                       30.017000                       34.619000
# 2865                       29.017000                       34.189000
# 2866                       30.529630                       36.181680
#
#       closed_shell_Cp600 (cal/mol/K)  closed_shell_Cp800 (cal/mol/K)  \
# 0                          44.234417                       48.821415
# 1                          44.234417                       48.821415
# 2                          39.309560                       44.059044
# 3                          78.070363                       87.443365
# 4                          37.592447                       42.375430
# ...                              ...                             ...
# 2862                       26.261000                       30.329000
# 2863                       39.185145                       45.162263
# 2864                       39.828000                       46.529000
# 2865                       38.448000                       45.419000
# 2866                       40.339270                       46.666770
#
#       closed_shell_Cp1000 (cal/mol/K)  closed_shell_Cp1500 (cal/mol/K)  \
# 0                           51.772505                        56.215621
# 1                           51.772505                        56.215621
# 2                           47.141300                        50.458700
# 3                           95.103078                       102.679981
# 4                           45.749560                        50.979006
# ...                               ...                              ...
# 2862                        33.199000                        37.574000
# 2863                        49.240044                        55.323950
# 2864                        51.356000                        56.349000
# 2865                        50.576000                        55.959000
# 2866                        51.760220                        58.299980
#
#       closed_shell_Sint298 (cal/mol/K)  \
# 0                           100.589618
# 1                           100.589618
# 2                            94.127419
# 3                           145.026864
# 4                            94.867820
# ...                                ...
# 2862                         61.950300
# 2863                         51.772385
# 2864                         75.140000
# 2865                         75.190000
# 2866                         70.312300
#
#                             closed_shell_thermo_comment
# 0     Thermo group additivity estimation: group(O2s-...
# 1     Thermo group additivity estimation: group(O2s-...
# 2     Thermo group additivity estimation: group(O2s-...
# 3     Thermo group additivity estimation: group(O2s-...
# 4     Thermo group additivity estimation: group(O2s-...
# ...                                                 ...
# 2862  Thermo group additivity estimation: group(Cds-...
# 2863  Thermo group additivity estimation: group(Cs-(...
# 2864  Thermo group additivity estimation: group(Cs-(...
# 2865  Thermo group additivity estimation: group(Cs-(...
# 2866  Thermo group additivity estimation: group(Cs-(...
#
# [2867 rows x 14 columns]

# %%
def thermo_source(comment):
    if "Thermo group additivity estimation" in comment:
        return "GAV"
    else:
        return comment
HBI_correction_df["closed_shell_thermo_source"] = HBI_correction_df["closed_shell_thermo_comment"].apply(thermo_source)
HBI_correction_df
# Out:
#                  radical_smiles   radical_resonance_smiles  \
# 0             [O]C(=O)OC(O)(O)O          [O]C(=O)OC(O)(O)O
# 1             [O]C(O)(O)OC(=O)O          [O]C(O)(O)OC(=O)O
# 2                O=C(O)O[C](O)O             O=C(O)O[C](O)O
# 3     CC(=O)OC(OO)C(=O)C(O)O[O]  CC(=O)OC(OO)C(=O)C(O)O[O]
# 4                O=[C]OC(O)(O)O             O=[C]OC(O)(O)O
# ...                         ...                        ...
# 2862                C1=C[CH]C=1                 [C]1=CC=C1
# 2863              C=C=C1C=[C]C1              C=C=C1C=[C]C1
# 2864             [CH2]C1=CC#CC1             [CH2]C1=CC#CC1
# 2865             [CH2]C1=CC#CC1              C=C1[CH]C#CC1
# 2866             [CH2]C1=CC#CC1              C=C1C=C=[C]C1
#
#           closed_shell_smiles  closed_shell_H298 (kcal/mol)  \
# 0             O=C(O)OC(O)(O)O                   -272.617591
# 1             O=C(O)OC(O)(O)O                   -272.617591
# 2                O=C(O)OC(O)O                   -231.363843
# 3     CC(=O)OC(OO)C(=O)C(O)OO                   -234.219312
# 4                O=COC(O)(O)O                   -216.499044
# ...                       ...                           ...
# 2862                 C1=CC=C1                    104.333500
# 2863              C=C=C1C=CC1                     91.366874
# 2864               CC1=CC#CC1                    131.227000
# 2865               C=C1CC#CC1                    136.767000
# 2866              C=C1C=C=CC1                    126.273400
#
#       closed_shell_S298 (cal/mol/K)  closed_shell_Cp300 (cal/mol/K)  \
# 0                         98.406448                       31.562314
# 1                         98.406448                       31.562314
# 2                         94.127419                       27.214474
# 3                        145.598548                       52.706616
# 4                         92.684651                       26.935163
# ...                             ...                             ...
# 2862                      57.818020                       15.504000
# 2863                      50.394958                       22.416919
# 2864                      72.956831                       23.409000
# 2865                      72.435147                       22.819000
# 2866                      68.934873                       23.109770
#
#       closed_shell_Cp400 (cal/mol/K)  closed_shell_Cp500 (cal/mol/K)  \
# 0                          36.827897                       41.095602
# 1                          36.827897                       41.095602
# 2                          31.965583                       36.032333
# 3                          62.438776                       71.442505
# 4                          30.962696                       34.637667
# ...                              ...                             ...
# 2862                       19.920000                       23.474000
# 2863                       29.489266                       35.000461
# 2864                       30.017000                       34.619000
# 2865                       29.017000                       34.189000
# 2866                       30.529630                       36.181680
#
#       closed_shell_Cp600 (cal/mol/K)  closed_shell_Cp800 (cal/mol/K)  \
# 0                          44.234417                       48.821415
# 1                          44.234417                       48.821415
# 2                          39.309560                       44.059044
# 3                          78.070363                       87.443365
# 4                          37.592447                       42.375430
# ...                              ...                             ...
# 2862                       26.261000                       30.329000
# 2863                       39.185145                       45.162263
# 2864                       39.828000                       46.529000
# 2865                       38.448000                       45.419000
# 2866                       40.339270                       46.666770
#
#       closed_shell_Cp1000 (cal/mol/K)  closed_shell_Cp1500 (cal/mol/K)  \
# 0                           51.772505                        56.215621
# 1                           51.772505                        56.215621
# 2                           47.141300                        50.458700
# 3                           95.103078                       102.679981
# 4                           45.749560                        50.979006
# ...                               ...                              ...
# 2862                        33.199000                        37.574000
# 2863                        49.240044                        55.323950
# 2864                        51.356000                        56.349000
# 2865                        50.576000                        55.959000
# 2866                        51.760220                        58.299980
#
#       closed_shell_Sint298 (cal/mol/K)  \
# 0                           100.589618
# 1                           100.589618
# 2                            94.127419
# 3                           145.026864
# 4                            94.867820
# ...                                ...
# 2862                         61.950300
# 2863                         51.772385
# 2864                         75.140000
# 2865                         75.190000
# 2866                         70.312300
#
#                             closed_shell_thermo_comment  \
# 0     Thermo group additivity estimation: group(O2s-...
# 1     Thermo group additivity estimation: group(O2s-...
# 2     Thermo group additivity estimation: group(O2s-...
# 3     Thermo group additivity estimation: group(O2s-...
# 4     Thermo group additivity estimation: group(O2s-...
# ...                                                 ...
# 2862  Thermo group additivity estimation: group(Cds-...
# 2863  Thermo group additivity estimation: group(Cs-(...
# 2864  Thermo group additivity estimation: group(Cs-(...
# 2865  Thermo group additivity estimation: group(Cs-(...
# 2866  Thermo group additivity estimation: group(Cs-(...
#
#      closed_shell_thermo_source
# 0                           GAV
# 1                           GAV
# 2                           GAV
# 3                           GAV
# 4                           GAV
# ...                         ...
# 2862                        GAV
# 2863                        GAV
# 2864                        GAV
# 2865                        GAV
# 2866                        GAV
#
# [2867 rows x 15 columns]

# %%
HBI_correction_df["closed_shell_thermo_source"].value_counts()
# Out:
# GAV                                           1864
# Thermo library: ../data/dong_pio_liang.py      876
# Thermo library: ../data/pang.py                 99
# Thermo library: ../data/johnson_g4.py           22
# Thermo library: ../data/johnson_cbs-qb3.py       6
# Name: closed_shell_thermo_source, dtype: int64

# %%
HBI_correction_df.to_csv("../data/hbi.csv", index=False)

# %% [markdown]
# # Derive HBI corrections

# %%
radical_df = pd.read_csv("../data/radical.csv")
radical_df
# Out:
#                          smiles  H298 (kcal/mol)  S298 (cal/mol/K)  \
# 0             [O]C(=O)OC(O)(O)O      -223.514126         93.816804
# 1             [O]C(O)(O)OC(=O)O      -223.423390         92.781436
# 2                O=C(O)O[C](O)O      -187.322869         88.139642
# 3     CC(=O)OC(OO)C(=O)C(O)O[O]      -185.660577        133.205064
# 4                O=[C]OC(O)(O)O      -180.497563         87.848805
# ...                         ...              ...               ...
# 2232             C=C=C1[CH]C1=C       148.970420         78.606070
# 2233                [CH]=C1C=C1       152.166735         66.134536
# 2234                C1=C[CH]C=1       156.106582         64.008341
# 2235              C=C=C1C=[C]C1       157.733085         76.210198
# 2236             [CH2]C1=CC#CC1       163.498344         74.586417
#
#       Sint298 (cal/mol/K)             source level_of_theory  \
# 0               95.999974  dong_pio_liang.py         CBS-QB3
# 1               92.781436  dong_pio_liang.py         CBS-QB3
# 2               89.517068  dong_pio_liang.py         CBS-QB3
# 3              132.633380  dong_pio_liang.py         CBS-QB3
# 4               90.031975  dong_pio_liang.py         CBS-QB3
# ...                   ...                ...             ...
# 2232            81.360924  dong_pio_liang.py         CBS-QB3
# 2233            67.511963  dong_pio_liang.py         CBS-QB3
# 2234            65.385768  dong_pio_liang.py         CBS-QB3
# 2235            77.587625  dong_pio_liang.py         CBS-QB3
# 2236            75.963844  dong_pio_liang.py         CBS-QB3
#
#       Cp300 (cal/mol/K)  Cp400 (cal/mol/K)  Cp500 (cal/mol/K)  \
# 0             33.926878          38.387673          41.508496
# 1             32.531179          37.569659          41.498443
# 2             28.973242          34.553073          38.746721
# 3             56.569703          66.028226          73.603744
# 4             32.378191          36.844343          39.334179
# ...                 ...                ...                ...
# 2232          25.185446          30.771706          34.989720
# 2233          16.390064          19.702535          22.399354
# 2234          14.653111          18.488757          21.562144
# 2235          22.675255          28.333884          32.976246
# 2236          22.606638          28.495118          33.391100
#
#       Cp600 (cal/mol/K)  Cp800 (cal/mol/K)  Cp1000 (cal/mol/K)  \
# 0             44.062390          47.779730           50.089328
# 1             44.710460          49.355989           52.184758
# 2             41.655671          45.237515           47.423507
# 3             79.772844          88.705511           94.174908
# 4             41.301130          44.143726           45.893560
# ...                 ...                ...                 ...
# 2232          38.456637          43.926501           47.843872
# 2233          24.484680          27.637313           29.841300
# 2234          23.855179          27.322032           29.749165
# 2235          36.811783          42.847715           47.149236
# 2236          37.327959          43.401164           47.644478
#
#       Cp1500 (cal/mol/K)  num_resonance
# 0              52.510168              1
# 1              54.821371              1
# 2              49.461069              1
# 3              99.503777              1
# 4              47.744589              1
# ...                  ...            ...
# 2232           53.411105              3
# 2233           32.891319              1
# 2234           33.017640              2
# 2235           53.155423              1
# 2236           53.388267              3
#
# [2237 rows x 14 columns]

# %%
HBI_correction_df = pd.read_csv("../data/hbi.csv")
HBI_correction_df
# Out:
#                  radical_smiles   radical_resonance_smiles  \
# 0             [O]C(=O)OC(O)(O)O          [O]C(=O)OC(O)(O)O
# 1             [O]C(O)(O)OC(=O)O          [O]C(O)(O)OC(=O)O
# 2                O=C(O)O[C](O)O             O=C(O)O[C](O)O
# 3     CC(=O)OC(OO)C(=O)C(O)O[O]  CC(=O)OC(OO)C(=O)C(O)O[O]
# 4                O=[C]OC(O)(O)O             O=[C]OC(O)(O)O
# ...                         ...                        ...
# 2862                C1=C[CH]C=1                 [C]1=CC=C1
# 2863              C=C=C1C=[C]C1              C=C=C1C=[C]C1
# 2864             [CH2]C1=CC#CC1             [CH2]C1=CC#CC1
# 2865             [CH2]C1=CC#CC1              C=C1[CH]C#CC1
# 2866             [CH2]C1=CC#CC1              C=C1C=C=[C]C1
#
#           closed_shell_smiles  closed_shell_H298 (kcal/mol)  \
# 0             O=C(O)OC(O)(O)O                   -272.617591
# 1             O=C(O)OC(O)(O)O                   -272.617591
# 2                O=C(O)OC(O)O                   -231.363843
# 3     CC(=O)OC(OO)C(=O)C(O)OO                   -234.219312
# 4                O=COC(O)(O)O                   -216.499044
# ...                       ...                           ...
# 2862                 C1=CC=C1                    104.333500
# 2863              C=C=C1C=CC1                     91.366874
# 2864               CC1=CC#CC1                    131.227000
# 2865               C=C1CC#CC1                    136.767000
# 2866              C=C1C=C=CC1                    126.273400
#
#       closed_shell_S298 (cal/mol/K)  closed_shell_Cp300 (cal/mol/K)  \
# 0                         98.406448                       31.562314
# 1                         98.406448                       31.562314
# 2                         94.127419                       27.214474
# 3                        145.598548                       52.706616
# 4                         92.684651                       26.935163
# ...                             ...                             ...
# 2862                      57.818020                       15.504000
# 2863                      50.394958                       22.416919
# 2864                      72.956831                       23.409000
# 2865                      72.435147                       22.819000
# 2866                      68.934873                       23.109770
#
#       closed_shell_Cp400 (cal/mol/K)  closed_shell_Cp500 (cal/mol/K)  \
# 0                          36.827897                       41.095602
# 1                          36.827897                       41.095602
# 2                          31.965583                       36.032333
# 3                          62.438776                       71.442505
# 4                          30.962696                       34.637667
# ...                              ...                             ...
# 2862                       19.920000                       23.474000
# 2863                       29.489266                       35.000461
# 2864                       30.017000                       34.619000
# 2865                       29.017000                       34.189000
# 2866                       30.529630                       36.181680
#
#       closed_shell_Cp600 (cal/mol/K)  closed_shell_Cp800 (cal/mol/K)  \
# 0                          44.234417                       48.821415
# 1                          44.234417                       48.821415
# 2                          39.309560                       44.059044
# 3                          78.070363                       87.443365
# 4                          37.592447                       42.375430
# ...                              ...                             ...
# 2862                       26.261000                       30.329000
# 2863                       39.185145                       45.162263
# 2864                       39.828000                       46.529000
# 2865                       38.448000                       45.419000
# 2866                       40.339270                       46.666770
#
#       closed_shell_Cp1000 (cal/mol/K)  closed_shell_Cp1500 (cal/mol/K)  \
# 0                           51.772505                        56.215621
# 1                           51.772505                        56.215621
# 2                           47.141300                        50.458700
# 3                           95.103078                       102.679981
# 4                           45.749560                        50.979006
# ...                               ...                              ...
# 2862                        33.199000                        37.574000
# 2863                        49.240044                        55.323950
# 2864                        51.356000                        56.349000
# 2865                        50.576000                        55.959000
# 2866                        51.760220                        58.299980
#
#       closed_shell_Sint298 (cal/mol/K)  \
# 0                           100.589618
# 1                           100.589618
# 2                            94.127419
# 3                           145.026864
# 4                            94.867820
# ...                                ...
# 2862                         61.950300
# 2863                         51.772385
# 2864                         75.140000
# 2865                         75.190000
# 2866                         70.312300
#
#                             closed_shell_thermo_comment  \
# 0     Thermo group additivity estimation: group(O2s-...
# 1     Thermo group additivity estimation: group(O2s-...
# 2     Thermo group additivity estimation: group(O2s-...
# 3     Thermo group additivity estimation: group(O2s-...
# 4     Thermo group additivity estimation: group(O2s-...
# ...                                                 ...
# 2862  Thermo group additivity estimation: group(Cds-...
# 2863  Thermo group additivity estimation: group(Cs-(...
# 2864  Thermo group additivity estimation: group(Cs-(...
# 2865  Thermo group additivity estimation: group(Cs-(...
# 2866  Thermo group additivity estimation: group(Cs-(...
#
#      closed_shell_thermo_source
# 0                           GAV
# 1                           GAV
# 2                           GAV
# 3                           GAV
# 4                           GAV
# ...                         ...
# 2862                        GAV
# 2863                        GAV
# 2864                        GAV
# 2865                        GAV
# 2866                        GAV
#
# [2867 rows x 15 columns]

# %%
temp_df = pd.DataFrame()

for column in radical_df.columns:
    temp_df[f"radical_{column}"] = radical_df[column]

temp_df
# Out:
#                  radical_smiles  radical_H298 (kcal/mol)  \
# 0             [O]C(=O)OC(O)(O)O              -223.514126
# 1             [O]C(O)(O)OC(=O)O              -223.423390
# 2                O=C(O)O[C](O)O              -187.322869
# 3     CC(=O)OC(OO)C(=O)C(O)O[O]              -185.660577
# 4                O=[C]OC(O)(O)O              -180.497563
# ...                         ...                      ...
# 2232             C=C=C1[CH]C1=C               148.970420
# 2233                [CH]=C1C=C1               152.166735
# 2234                C1=C[CH]C=1               156.106582
# 2235              C=C=C1C=[C]C1               157.733085
# 2236             [CH2]C1=CC#CC1               163.498344
#
#       radical_S298 (cal/mol/K)  radical_Sint298 (cal/mol/K)  \
# 0                    93.816804                    95.999974
# 1                    92.781436                    92.781436
# 2                    88.139642                    89.517068
# 3                   133.205064                   132.633380
# 4                    87.848805                    90.031975
# ...                        ...                          ...
# 2232                 78.606070                    81.360924
# 2233                 66.134536                    67.511963
# 2234                 64.008341                    65.385768
# 2235                 76.210198                    77.587625
# 2236                 74.586417                    75.963844
#
#          radical_source radical_level_of_theory  radical_Cp300 (cal/mol/K)  \
# 0     dong_pio_liang.py                 CBS-QB3                  33.926878
# 1     dong_pio_liang.py                 CBS-QB3                  32.531179
# 2     dong_pio_liang.py                 CBS-QB3                  28.973242
# 3     dong_pio_liang.py                 CBS-QB3                  56.569703
# 4     dong_pio_liang.py                 CBS-QB3                  32.378191
# ...                 ...                     ...                        ...
# 2232  dong_pio_liang.py                 CBS-QB3                  25.185446
# 2233  dong_pio_liang.py                 CBS-QB3                  16.390064
# 2234  dong_pio_liang.py                 CBS-QB3                  14.653111
# 2235  dong_pio_liang.py                 CBS-QB3                  22.675255
# 2236  dong_pio_liang.py                 CBS-QB3                  22.606638
#
#       radical_Cp400 (cal/mol/K)  radical_Cp500 (cal/mol/K)  \
# 0                     38.387673                  41.508496
# 1                     37.569659                  41.498443
# 2                     34.553073                  38.746721
# 3                     66.028226                  73.603744
# 4                     36.844343                  39.334179
# ...                         ...                        ...
# 2232                  30.771706                  34.989720
# 2233                  19.702535                  22.399354
# 2234                  18.488757                  21.562144
# 2235                  28.333884                  32.976246
# 2236                  28.495118                  33.391100
#
#       radical_Cp600 (cal/mol/K)  radical_Cp800 (cal/mol/K)  \
# 0                     44.062390                  47.779730
# 1                     44.710460                  49.355989
# 2                     41.655671                  45.237515
# 3                     79.772844                  88.705511
# 4                     41.301130                  44.143726
# ...                         ...                        ...
# 2232                  38.456637                  43.926501
# 2233                  24.484680                  27.637313
# 2234                  23.855179                  27.322032
# 2235                  36.811783                  42.847715
# 2236                  37.327959                  43.401164
#
#       radical_Cp1000 (cal/mol/K)  radical_Cp1500 (cal/mol/K)  \
# 0                      50.089328                   52.510168
# 1                      52.184758                   54.821371
# 2                      47.423507                   49.461069
# 3                      94.174908                   99.503777
# 4                      45.893560                   47.744589
# ...                          ...                         ...
# 2232                   47.843872                   53.411105
# 2233                   29.841300                   32.891319
# 2234                   29.749165                   33.017640
# 2235                   47.149236                   53.155423
# 2236                   47.644478                   53.388267
#
#       radical_num_resonance
# 0                         1
# 1                         1
# 2                         1
# 3                         1
# 4                         1
# ...                     ...
# 2232                      3
# 2233                      1
# 2234                      2
# 2235                      1
# 2236                      3
#
# [2237 rows x 14 columns]

# %%
HBI_correction_df = HBI_correction_df.merge(temp_df, how="left", on="radical_smiles")
HBI_correction_df
# Out:
#                  radical_smiles   radical_resonance_smiles  \
# 0             [O]C(=O)OC(O)(O)O          [O]C(=O)OC(O)(O)O
# 1             [O]C(O)(O)OC(=O)O          [O]C(O)(O)OC(=O)O
# 2                O=C(O)O[C](O)O             O=C(O)O[C](O)O
# 3     CC(=O)OC(OO)C(=O)C(O)O[O]  CC(=O)OC(OO)C(=O)C(O)O[O]
# 4                O=[C]OC(O)(O)O             O=[C]OC(O)(O)O
# ...                         ...                        ...
# 2862                C1=C[CH]C=1                 [C]1=CC=C1
# 2863              C=C=C1C=[C]C1              C=C=C1C=[C]C1
# 2864             [CH2]C1=CC#CC1             [CH2]C1=CC#CC1
# 2865             [CH2]C1=CC#CC1              C=C1[CH]C#CC1
# 2866             [CH2]C1=CC#CC1              C=C1C=C=[C]C1
#
#           closed_shell_smiles  closed_shell_H298 (kcal/mol)  \
# 0             O=C(O)OC(O)(O)O                   -272.617591
# 1             O=C(O)OC(O)(O)O                   -272.617591
# 2                O=C(O)OC(O)O                   -231.363843
# 3     CC(=O)OC(OO)C(=O)C(O)OO                   -234.219312
# 4                O=COC(O)(O)O                   -216.499044
# ...                       ...                           ...
# 2862                 C1=CC=C1                    104.333500
# 2863              C=C=C1C=CC1                     91.366874
# 2864               CC1=CC#CC1                    131.227000
# 2865               C=C1CC#CC1                    136.767000
# 2866              C=C1C=C=CC1                    126.273400
#
#       closed_shell_S298 (cal/mol/K)  closed_shell_Cp300 (cal/mol/K)  \
# 0                         98.406448                       31.562314
# 1                         98.406448                       31.562314
# 2                         94.127419                       27.214474
# 3                        145.598548                       52.706616
# 4                         92.684651                       26.935163
# ...                             ...                             ...
# 2862                      57.818020                       15.504000
# 2863                      50.394958                       22.416919
# 2864                      72.956831                       23.409000
# 2865                      72.435147                       22.819000
# 2866                      68.934873                       23.109770
#
#       closed_shell_Cp400 (cal/mol/K)  closed_shell_Cp500 (cal/mol/K)  \
# 0                          36.827897                       41.095602
# 1                          36.827897                       41.095602
# 2                          31.965583                       36.032333
# 3                          62.438776                       71.442505
# 4                          30.962696                       34.637667
# ...                              ...                             ...
# 2862                       19.920000                       23.474000
# 2863                       29.489266                       35.000461
# 2864                       30.017000                       34.619000
# 2865                       29.017000                       34.189000
# 2866                       30.529630                       36.181680
#
#       closed_shell_Cp600 (cal/mol/K)  closed_shell_Cp800 (cal/mol/K)  ...  \
# 0                          44.234417                       48.821415  ...
# 1                          44.234417                       48.821415  ...
# 2                          39.309560                       44.059044  ...
# 3                          78.070363                       87.443365  ...
# 4                          37.592447                       42.375430  ...
# ...                              ...                             ...  ...
# 2862                       26.261000                       30.329000  ...
# 2863                       39.185145                       45.162263  ...
# 2864                       39.828000                       46.529000  ...
# 2865                       38.448000                       45.419000  ...
# 2866                       40.339270                       46.666770  ...
#
#          radical_source  radical_level_of_theory  radical_Cp300 (cal/mol/K)  \
# 0     dong_pio_liang.py                  CBS-QB3                  33.926878
# 1     dong_pio_liang.py                  CBS-QB3                  32.531179
# 2     dong_pio_liang.py                  CBS-QB3                  28.973242
# 3     dong_pio_liang.py                  CBS-QB3                  56.569703
# 4     dong_pio_liang.py                  CBS-QB3                  32.378191
# ...                 ...                      ...                        ...
# 2862  dong_pio_liang.py                  CBS-QB3                  14.653111
# 2863  dong_pio_liang.py                  CBS-QB3                  22.675255
# 2864  dong_pio_liang.py                  CBS-QB3                  22.606638
# 2865  dong_pio_liang.py                  CBS-QB3                  22.606638
# 2866  dong_pio_liang.py                  CBS-QB3                  22.606638
#
#      radical_Cp400 (cal/mol/K) radical_Cp500 (cal/mol/K)  \
# 0                    38.387673                 41.508496
# 1                    37.569659                 41.498443
# 2                    34.553073                 38.746721
# 3                    66.028226                 73.603744
# 4                    36.844343                 39.334179
# ...                        ...                       ...
# 2862                 18.488757                 21.562144
# 2863                 28.333884                 32.976246
# 2864                 28.495118                 33.391100
# 2865                 28.495118                 33.391100
# 2866                 28.495118                 33.391100
#
#       radical_Cp600 (cal/mol/K)  radical_Cp800 (cal/mol/K)  \
# 0                     44.062390                  47.779730
# 1                     44.710460                  49.355989
# 2                     41.655671                  45.237515
# 3                     79.772844                  88.705511
# 4                     41.301130                  44.143726
# ...                         ...                        ...
# 2862                  23.855179                  27.322032
# 2863                  36.811783                  42.847715
# 2864                  37.327959                  43.401164
# 2865                  37.327959                  43.401164
# 2866                  37.327959                  43.401164
#
#       radical_Cp1000 (cal/mol/K) radical_Cp1500 (cal/mol/K)  \
# 0                      50.089328                  52.510168
# 1                      52.184758                  54.821371
# 2                      47.423507                  49.461069
# 3                      94.174908                  99.503777
# 4                      45.893560                  47.744589
# ...                          ...                        ...
# 2862                   29.749165                  33.017640
# 2863                   47.149236                  53.155423
# 2864                   47.644478                  53.388267
# 2865                   47.644478                  53.388267
# 2866                   47.644478                  53.388267
#
#      radical_num_resonance
# 0                        1
# 1                        1
# 2                        1
# 3                        1
# 4                        1
# ...                    ...
# 2862                     2
# 2863                     1
# 2864                     3
# 2865                     3
# 2866                     3
#
# [2867 rows x 28 columns]

# %%
properties = ["H298 (kcal/mol)", "Sint298 (cal/mol/K)"]
for T in Ts:
    properties.append(f"Cp{T} (cal/mol/K)")

for prop in properties:
    HBI_correction_df[f"HBI_{prop}"] = HBI_correction_df[f"radical_{prop}"] - HBI_correction_df[f"closed_shell_{prop}"]
    
HBI_correction_df
# Out:
#                  radical_smiles   radical_resonance_smiles  \
# 0             [O]C(=O)OC(O)(O)O          [O]C(=O)OC(O)(O)O
# 1             [O]C(O)(O)OC(=O)O          [O]C(O)(O)OC(=O)O
# 2                O=C(O)O[C](O)O             O=C(O)O[C](O)O
# 3     CC(=O)OC(OO)C(=O)C(O)O[O]  CC(=O)OC(OO)C(=O)C(O)O[O]
# 4                O=[C]OC(O)(O)O             O=[C]OC(O)(O)O
# ...                         ...                        ...
# 2862                C1=C[CH]C=1                 [C]1=CC=C1
# 2863              C=C=C1C=[C]C1              C=C=C1C=[C]C1
# 2864             [CH2]C1=CC#CC1             [CH2]C1=CC#CC1
# 2865             [CH2]C1=CC#CC1              C=C1[CH]C#CC1
# 2866             [CH2]C1=CC#CC1              C=C1C=C=[C]C1
#
#           closed_shell_smiles  closed_shell_H298 (kcal/mol)  \
# 0             O=C(O)OC(O)(O)O                   -272.617591
# 1             O=C(O)OC(O)(O)O                   -272.617591
# 2                O=C(O)OC(O)O                   -231.363843
# 3     CC(=O)OC(OO)C(=O)C(O)OO                   -234.219312
# 4                O=COC(O)(O)O                   -216.499044
# ...                       ...                           ...
# 2862                 C1=CC=C1                    104.333500
# 2863              C=C=C1C=CC1                     91.366874
# 2864               CC1=CC#CC1                    131.227000
# 2865               C=C1CC#CC1                    136.767000
# 2866              C=C1C=C=CC1                    126.273400
#
#       closed_shell_S298 (cal/mol/K)  closed_shell_Cp300 (cal/mol/K)  \
# 0                         98.406448                       31.562314
# 1                         98.406448                       31.562314
# 2                         94.127419                       27.214474
# 3                        145.598548                       52.706616
# 4                         92.684651                       26.935163
# ...                             ...                             ...
# 2862                      57.818020                       15.504000
# 2863                      50.394958                       22.416919
# 2864                      72.956831                       23.409000
# 2865                      72.435147                       22.819000
# 2866                      68.934873                       23.109770
#
#       closed_shell_Cp400 (cal/mol/K)  closed_shell_Cp500 (cal/mol/K)  \
# 0                          36.827897                       41.095602
# 1                          36.827897                       41.095602
# 2                          31.965583                       36.032333
# 3                          62.438776                       71.442505
# 4                          30.962696                       34.637667
# ...                              ...                             ...
# 2862                       19.920000                       23.474000
# 2863                       29.489266                       35.000461
# 2864                       30.017000                       34.619000
# 2865                       29.017000                       34.189000
# 2866                       30.529630                       36.181680
#
#       closed_shell_Cp600 (cal/mol/K)  closed_shell_Cp800 (cal/mol/K)  ...  \
# 0                          44.234417                       48.821415  ...
# 1                          44.234417                       48.821415  ...
# 2                          39.309560                       44.059044  ...
# 3                          78.070363                       87.443365  ...
# 4                          37.592447                       42.375430  ...
# ...                              ...                             ...  ...
# 2862                       26.261000                       30.329000  ...
# 2863                       39.185145                       45.162263  ...
# 2864                       39.828000                       46.529000  ...
# 2865                       38.448000                       45.419000  ...
# 2866                       40.339270                       46.666770  ...
#
#       radical_num_resonance  HBI_H298 (kcal/mol)  HBI_Sint298 (cal/mol/K)  \
# 0                         1            49.103465                -4.589644
# 1                         1            49.194200                -7.808181
# 2                         1            44.040974                -4.610350
# 3                         1            48.558735               -12.393484
# 4                         1            36.001481                -4.835845
# ...                     ...                  ...                      ...
# 2862                      2            51.773082                 3.435468
# 2863                      1            66.366211                25.815240
# 2864                      3            32.271344                 0.823844
# 2865                      3            26.731344                 0.773844
# 2866                      3            37.224944                 5.651544
#
#      HBI_Cp300 (cal/mol/K) HBI_Cp400 (cal/mol/K)  HBI_Cp500 (cal/mol/K)  \
# 0                 2.364565              1.559776               0.412894
# 1                 0.968866              0.741762               0.402841
# 2                 1.758768              2.587490               2.714389
# 3                 3.863088              3.589450               2.161239
# 4                 5.443029              5.881647               4.696512
# ...                    ...                   ...                    ...
# 2862             -0.850889             -1.431243              -1.911856
# 2863              0.258337             -1.155381              -2.024215
# 2864             -0.802362             -1.521882              -1.227900
# 2865             -0.212362             -0.521882              -0.797900
# 2866             -0.503132             -2.034512              -2.790580
#
#       HBI_Cp600 (cal/mol/K)  HBI_Cp800 (cal/mol/K) HBI_Cp1000 (cal/mol/K)  \
# 0                 -0.172027              -1.041685              -1.683176
# 1                  0.476043               0.534574               0.412253
# 2                  2.346110               1.178471               0.282207
# 3                  1.702481               1.262146              -0.928170
# 4                  3.708683               1.768296               0.144000
# ...                     ...                    ...                    ...
# 2862              -2.405821              -3.006968              -3.449835
# 2863              -2.373362              -2.314548              -2.090808
# 2864              -2.500041              -3.127836              -3.711522
# 2865              -1.120041              -2.017836              -2.931522
# 2866              -3.011311              -3.265606              -4.115742
#
#      HBI_Cp1500 (cal/mol/K)
# 0                 -3.705453
# 1                 -1.394250
# 2                 -0.997631
# 3                 -3.176204
# 4                 -3.234417
# ...                     ...
# 2862              -4.556360
# 2863              -2.168527
# 2864              -2.960733
# 2865              -2.570733
# 2866              -4.911713
#
# [2867 rows x 37 columns]

# %%
HBI_correction_df.to_csv("../data/hbi.csv", index=False)

# %% [markdown]
# # Stats

# %%
HBI_correction_df = pd.read_csv("../data/hbi.csv")
HBI_correction_df
# Out:
#                  radical_smiles   radical_resonance_smiles  \
# 0             [O]C(=O)OC(O)(O)O          [O]C(=O)OC(O)(O)O
# 1             [O]C(O)(O)OC(=O)O          [O]C(O)(O)OC(=O)O
# 2                O=C(O)O[C](O)O             O=C(O)O[C](O)O
# 3     CC(=O)OC(OO)C(=O)C(O)O[O]  CC(=O)OC(OO)C(=O)C(O)O[O]
# 4                O=[C]OC(O)(O)O             O=[C]OC(O)(O)O
# ...                         ...                        ...
# 2862                C1=C[CH]C=1                 [C]1=CC=C1
# 2863              C=C=C1C=[C]C1              C=C=C1C=[C]C1
# 2864             [CH2]C1=CC#CC1             [CH2]C1=CC#CC1
# 2865             [CH2]C1=CC#CC1              C=C1[CH]C#CC1
# 2866             [CH2]C1=CC#CC1              C=C1C=C=[C]C1
#
#           closed_shell_smiles  closed_shell_H298 (kcal/mol)  \
# 0             O=C(O)OC(O)(O)O                   -272.617591
# 1             O=C(O)OC(O)(O)O                   -272.617591
# 2                O=C(O)OC(O)O                   -231.363843
# 3     CC(=O)OC(OO)C(=O)C(O)OO                   -234.219312
# 4                O=COC(O)(O)O                   -216.499044
# ...                       ...                           ...
# 2862                 C1=CC=C1                    104.333500
# 2863              C=C=C1C=CC1                     91.366874
# 2864               CC1=CC#CC1                    131.227000
# 2865               C=C1CC#CC1                    136.767000
# 2866              C=C1C=C=CC1                    126.273400
#
#       closed_shell_S298 (cal/mol/K)  closed_shell_Cp300 (cal/mol/K)  \
# 0                         98.406448                       31.562314
# 1                         98.406448                       31.562314
# 2                         94.127419                       27.214474
# 3                        145.598548                       52.706616
# 4                         92.684651                       26.935163
# ...                             ...                             ...
# 2862                      57.818020                       15.504000
# 2863                      50.394958                       22.416919
# 2864                      72.956831                       23.409000
# 2865                      72.435147                       22.819000
# 2866                      68.934873                       23.109770
#
#       closed_shell_Cp400 (cal/mol/K)  closed_shell_Cp500 (cal/mol/K)  \
# 0                          36.827897                       41.095602
# 1                          36.827897                       41.095602
# 2                          31.965583                       36.032333
# 3                          62.438776                       71.442505
# 4                          30.962696                       34.637667
# ...                              ...                             ...
# 2862                       19.920000                       23.474000
# 2863                       29.489266                       35.000461
# 2864                       30.017000                       34.619000
# 2865                       29.017000                       34.189000
# 2866                       30.529630                       36.181680
#
#       closed_shell_Cp600 (cal/mol/K)  closed_shell_Cp800 (cal/mol/K)  ...  \
# 0                          44.234417                       48.821415  ...
# 1                          44.234417                       48.821415  ...
# 2                          39.309560                       44.059044  ...
# 3                          78.070363                       87.443365  ...
# 4                          37.592447                       42.375430  ...
# ...                              ...                             ...  ...
# 2862                       26.261000                       30.329000  ...
# 2863                       39.185145                       45.162263  ...
# 2864                       39.828000                       46.529000  ...
# 2865                       38.448000                       45.419000  ...
# 2866                       40.339270                       46.666770  ...
#
#       radical_num_resonance  HBI_H298 (kcal/mol)  HBI_Sint298 (cal/mol/K)  \
# 0                         1            49.103465                -4.589644
# 1                         1            49.194200                -7.808181
# 2                         1            44.040974                -4.610350
# 3                         1            48.558735               -12.393484
# 4                         1            36.001481                -4.835845
# ...                     ...                  ...                      ...
# 2862                      2            51.773082                 3.435468
# 2863                      1            66.366211                25.815240
# 2864                      3            32.271344                 0.823844
# 2865                      3            26.731344                 0.773844
# 2866                      3            37.224944                 5.651544
#
#      HBI_Cp300 (cal/mol/K) HBI_Cp400 (cal/mol/K)  HBI_Cp500 (cal/mol/K)  \
# 0                 2.364565              1.559776               0.412894
# 1                 0.968866              0.741762               0.402841
# 2                 1.758768              2.587490               2.714389
# 3                 3.863088              3.589450               2.161239
# 4                 5.443029              5.881647               4.696512
# ...                    ...                   ...                    ...
# 2862             -0.850889             -1.431243              -1.911856
# 2863              0.258337             -1.155381              -2.024215
# 2864             -0.802362             -1.521882              -1.227900
# 2865             -0.212362             -0.521882              -0.797900
# 2866             -0.503132             -2.034512              -2.790580
#
#       HBI_Cp600 (cal/mol/K)  HBI_Cp800 (cal/mol/K) HBI_Cp1000 (cal/mol/K)  \
# 0                 -0.172027              -1.041685              -1.683176
# 1                  0.476043               0.534574               0.412253
# 2                  2.346110               1.178471               0.282207
# 3                  1.702481               1.262146              -0.928170
# 4                  3.708683               1.768296               0.144000
# ...                     ...                    ...                    ...
# 2862              -2.405821              -3.006968              -3.449835
# 2863              -2.373362              -2.314548              -2.090808
# 2864              -2.500041              -3.127836              -3.711522
# 2865              -1.120041              -2.017836              -2.931522
# 2866              -3.011311              -3.265606              -4.115742
#
#      HBI_Cp1500 (cal/mol/K)
# 0                 -3.705453
# 1                 -1.394250
# 2                 -0.997631
# 3                 -3.176204
# 4                 -3.234417
# ...                     ...
# 2862              -4.556360
# 2863              -2.168527
# 2864              -2.960733
# 2865              -2.570733
# 2866              -4.911713
#
# [2867 rows x 37 columns]

# %%
HBI_correction_df["closed_shell_thermo_source"].value_counts()
# Out:
# GAV                                           1864
# Thermo library: ../data/dong_pio_liang.py      876
# Thermo library: ../data/pang.py                 99
# Thermo library: ../data/johnson_g4.py           22
# Thermo library: ../data/johnson_cbs-qb3.py       6
# Name: closed_shell_thermo_source, dtype: int64

# %%
876+99+6
# Out:
# 981
